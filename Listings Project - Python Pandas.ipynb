# %%
import pandas as pd

# %%
df = pd.read_table(r"C:\Users\usmaa\Downloads\listings.csv", sep=',')
df
# Out:
#              id                            listing_url     scrape_id  \
# 0          2595      https://www.airbnb.com/rooms/2595  2.020000e+13
# 1          3831      https://www.airbnb.com/rooms/3831  2.020000e+13
# 2          5121      https://www.airbnb.com/rooms/5121  2.020000e+13
# 3          5136      https://www.airbnb.com/rooms/5136  2.020000e+13
# 4          5178      https://www.airbnb.com/rooms/5178  2.020000e+13
# ...         ...                                    ...           ...
# 11942  32423962  https://www.airbnb.com/rooms/32423962  2.020000e+13
# 11943  32426202  https://www.airbnb.com/rooms/32426202  2.020000e+13
# 11944  32427326  https://www.airbnb.com/rooms/32427326  2.020000e+13
# 11945  32427478  https://www.airbnb.com/rooms/32427478  2.020000e+13
# 11946  32434711  https://www.airbnb.com/rooms/32434711  2.020000e+13
#
#       last_scraped                                               name  \
# ...

# %%
df.head(10)
# Out:
#      id                        listing_url     scrape_id last_scraped  \
# 0  2595  https://www.airbnb.com/rooms/2595  2.020000e+13   05/12/2021
# 1  3831  https://www.airbnb.com/rooms/3831  2.020000e+13   05/12/2021
# 2  5121  https://www.airbnb.com/rooms/5121  2.020000e+13   05/12/2021
# 3  5136  https://www.airbnb.com/rooms/5136  2.020000e+13   05/12/2021
# 4  5178  https://www.airbnb.com/rooms/5178  2.020000e+13   05/12/2021
# 5  5203  https://www.airbnb.com/rooms/5203  2.020000e+13   05/12/2021
# 6  5803  https://www.airbnb.com/rooms/5803  2.020000e+13   05/12/2021
# 7  6848  https://www.airbnb.com/rooms/6848  2.020000e+13   05/12/2021
# 8  6872  https://www.airbnb.com/rooms/6872  2.020000e+13   05/12/2021
# 9  6990  https://www.airbnb.com/rooms/6990  2.020000e+13   05/12/2021
#
#                                                 name  \
# 0                              Skylit Midtown Castle
# 1  Whole flr w/private bdrm, bath & kitchen(pls r...
# ...

# %%
#first 10 rows above

# %%
#last 5 rows below

# %%
df.tail()
# Out:
#              id                            listing_url     scrape_id  \
# 11942  32423962  https://www.airbnb.com/rooms/32423962  2.020000e+13
# 11943  32426202  https://www.airbnb.com/rooms/32426202  2.020000e+13
# 11944  32427326  https://www.airbnb.com/rooms/32427326  2.020000e+13
# 11945  32427478  https://www.airbnb.com/rooms/32427478  2.020000e+13
# 11946  32434711  https://www.airbnb.com/rooms/32434711  2.020000e+13
#
#       last_scraped                                               name  \
# 11942   05/12/2021     Cozy&Bright room in Queens♪Good subway access!
# 11943   05/12/2021      Modern 2 Bedroom Walk in. 3 min from Subway !
# 11944   04/12/2021            Little Italy room -Center of everything
# 11945   05/12/2021                                      Brooklyn home
# 11946   04/12/2021  CLEAN Studio Resort in Manhattan-Wyndham Midto...
#
#                                              description  \
# 11942  This comfortable room is prepared in November ...
# ...

# %%
#Printing 2 specific columns

# %%
df[['host_id', 'name']]
# Out:
#          host_id                                               name
# 0           2845                              Skylit Midtown Castle
# 1           4869  Whole flr w/private bdrm, bath & kitchen(pls r...
# 2           7356                                    BlissArtsSpace!
# 3           7378           Spacious Brooklyn Duplex, Patio + Garden
# 4           8967                   Large Furnished Room Near B'way
# ...          ...                                                ...
# 11942  200239515     Cozy&Bright room in Queens♪Good subway access!
# 11943    9289171      Modern 2 Bedroom Walk in. 3 min from Subway !
# 11944   30949138            Little Italy room -Center of everything
# 11945  243556325                                      Brooklyn home
# 11946  243627109  CLEAN Studio Resort in Manhattan-Wyndham Midto...
#
# [11947 rows x 2 columns]

# %%
#summary of the data frame

# %%
df.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  1.194700e+04  1.194700e+04  1.194700e+04         11931.000000
# mean   8.150322e+06  2.020000e+13  2.453555e+07             5.359651
# std    5.180646e+06  0.000000e+00  2.766377e+07            34.822067
# min    2.595000e+03  2.020000e+13  2.571000e+03             0.000000
# 25%    3.810081e+06  2.020000e+13  4.126700e+06             1.000000
# 50%    8.016747e+06  2.020000e+13  1.475801e+07             1.000000
# 75%    1.255212e+07  2.020000e+13  3.667133e+07             2.000000
# max    3.243471e+07  2.020000e+13  3.043856e+08          2273.000000
#
#        host_total_listings_count      latitude     longitude  accommodates  \
# count               11931.000000  11947.000000  11947.000000  11947.000000
# mean                    5.359651     40.729149    -73.956678      2.716665
# std                    34.822067      0.053871      0.040306      1.676746
# ...

# %%
#mean of reviewscoresvalue

# %%
df['review_scores_value'].mean()
# Out:
# 4.672482873157566

# %%
#mean of reviewsscoresvalue

# %%
df['review_scores_value'].median()
# Out:
# 4.755

# %%
#rows with review_scores_value less than 4

# %%
df.query('review_scores_value<4')
# Out:
#              id                            listing_url     scrape_id  \
# 80        36442     https://www.airbnb.com/rooms/36442  2.020000e+13
# 357      231154    https://www.airbnb.com/rooms/231154  2.020000e+13
# 486      295231    https://www.airbnb.com/rooms/295231  2.020000e+13
# 496      302280    https://www.airbnb.com/rooms/302280  2.020000e+13
# 629      462454    https://www.airbnb.com/rooms/462454  2.020000e+13
# ...         ...                                    ...           ...
# 11771  17330186  https://www.airbnb.com/rooms/17330186  2.020000e+13
# 11784  17381819  https://www.airbnb.com/rooms/17381819  2.020000e+13
# 11849  17524075  https://www.airbnb.com/rooms/17524075  2.020000e+13
# 11939  32410156  https://www.airbnb.com/rooms/32410156  2.020000e+13
# 11942  32423962  https://www.airbnb.com/rooms/32423962  2.020000e+13
#
#       last_scraped                                               name  \
# ...

# %%
#max value of availabilities column

# first select all the columns between A : B [see below]
#df.loc[:, 'instant_bookable':'calculated_host_listings_count_shared_rooms']
# all the relevant columns: instant_bookable	calculated_host_listings_count	calculated_host_listings_count_entire_homes	calculated_host_listings_count_private_rooms	calculated_host_listings_count_shared_rooms

# second, find the max() value in all columns

# %%
#df.loc['instant_bookable'== t], df.loc[:,'instant_bookable' : 'calculated_host_listings_count_shared_rooms'].max()
# I tried to find the count of instant_bookable as the max only appears as 't'.

# %%
df.loc[:,'instant_bookable':'calculated_host_listings_count_shared_rooms'].max()
# Out:
# instant_bookable                                  t
# calculated_host_listings_count                  308
# calculated_host_listings_count_entire_homes     308
# calculated_host_listings_count_private_rooms    135
# calculated_host_listings_count_shared_rooms       7
# dtype: object

# %%
true_count = df['instant_bookable'].count()
print(true_count)
# Out:
# 11947

# %%
#I need to somehow replace the true_count for the bool column 'instant_bookable' with the instant_bookable element in the summary max() list I have provided at [27].

# %%
#change one column datatype to date

# I don't want to mess up the table but you would do this by df['my_column']= pd.to_datetime(df['my_column'])

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\usmaa\Documents\Just IT data tech bootcamp Dec 2023 - Mar 2024\Project Datasets - see onedrive too\Countries of the World\countries of the world.csv")
df
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df = pd.read_csv(r"C:\Users\usmaa\Documents\Just IT data tech bootcamp Dec 2023 - Mar 2024\Project Datasets - see onedrive too\Countries of the World\countries of the world.txt")
#       2 df
#
# ...
